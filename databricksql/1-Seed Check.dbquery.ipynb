-- %% [markdown]
-- Row count the seeded files

-- %%
SELECT 'raw_customers', COUNT(*) FROM raw_customers
UNION 
SELECT 'raw_orders', COUNT(*) FROM raw_orders
UNION 
SELECT 'raw_payments', COUNT(*) FROM raw_payments
UNION
SELECT 'raw_notes', COUNT(*) FROM raw_notes;
